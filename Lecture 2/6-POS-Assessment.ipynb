# %% [markdown]
# # Parts of Speech Assessment

# %% [markdown]
# For this assessment we'll be using the short story [The Tale of Peter Rabbit](https://en.wikipedia.org/wiki/The_Tale_of_Peter_Rabbit) by Beatrix Potter (1902). <br>The story is in the public domain; the text file was obtained from [Project Gutenberg](https://www.gutenberg.org/ebooks/14838.txt.utf-8).

# %%
# RUN THIS CELL to perform standard imports:
import spacy
nlp = spacy.load('en_core_web_sm')
from spacy import displacy

# %% [markdown]
# **1. Create a Doc object from the file `peterrabbit.txt`**<br>
# > HINT: Use `with open('../TextFiles/peterrabbit.txt') as f:`

# %%
with open('../TextFiles/peterrabbit.txt') as file:
    doc = nlp(file.read())
    displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Tale of Peter Rabbit
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
# , by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Beatrix Potter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  (
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1902
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ).</br></br>Once upon a time there were
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     four
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  little Rabbits, and their names</br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     were--
#
#           Flopsy
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,</br>
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mopsy
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,</br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cotton
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# -tail,</br>and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Peter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# .</br></br>They lived with their Mother in a sand-bank, underneath the root of a</br>very big fir-tree.</br></br>'Now my dears,' said old Mrs. Rabbit
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one morning
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
# , 'you may go into</br>the fields or down the lane, but don't go into Mr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     McGregor
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# 's garden:</br>your Father had an accident there; he was put in a pie by Mrs.</br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     McGregor
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# .'</br></br>'Now run along, and don't get into mischief. I am going out.'</br></br>Then old Mrs.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Rabbit
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  took a basket and her umbrella, and went through</br>the wood to the baker's. She bought a loaf of brown bread and
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     five
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# </br>currant buns.</br></br>
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Flopsy
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mopsy
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , and
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cottontail
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , who were good little bunnies, went</br>down the lane to gather blackberries:</br></br>But
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Peter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , who was very naughty, ran straight away to Mr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     McGregor
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# 's</br>garden, and squeezed under the gate!</br></br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     First
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  he ate some lettuces and some
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     French
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  beans; and then he ate</br>some radishes;</br></br>And then, feeling rather sick, he went to look for some parsley.</br></br>But round the end of a cucumber frame, whom should he meet but Mr.</br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     McGregor
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# !</br></br>Mr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     McGregor
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  was on his hands and knees planting out young cabbages,</br>but he jumped up and ran af

# %% [markdown]
# **2. For every token in the third sentence, print the token text, the POS tag, the fine-grained TAG tag, and the description of the fine-grained tag.**

# %%
# Enter your code here:
for token in list(doc.sents)[2]:
    print("{:<10} {:<10} {:<10} {:<10}".format(token.text, token.pos_, token.tag_, spacy.explain(token.tag_)))
# Out:
# They       PRON       PRP        pronoun, personal
# lived      VERB       VBD        verb, past tense
# with       ADP        IN         conjunction, subordinating or preposition
# their      PRON       PRP$       pronoun, possessive
# Mother     NOUN       NN         noun, singular or mass
# in         ADP        IN         conjunction, subordinating or preposition
# a          DET        DT         determiner
# sand       NOUN       NN         noun, singular or mass
# -          PUNCT      HYPH       punctuation mark, hyphen
# bank       NOUN       NN         noun, singular or mass
# ,          PUNCT      ,          punctuation mark, comma
# underneath ADP        IN         conjunction, subordinating or preposition
# the        DET        DT         determiner
# root       NOUN       NN         noun, singular or mass
# of         ADP        IN         conjunction, subordinating or preposition
# a          DET        DT         determiner
#
#           SPACE      _SP        whitespace
# very       ADV        RB         adverb
# big        ADJ        JJ         adjective (English), other noun-modifier (Chinese)
# fir        NOUN       NN         noun, singular or mass
# -          PUNCT      HYPH       punctuation mark, hyphen
# tree       NOUN       NN         noun, singular or mass
# .          PUNCT      .          punctuation mark, sentence closer
#
#
#          SPACE      _SP        whitespace

# %% [markdown]
# **3. Provide a frequency list of POS tags from the entire document**

# %%
POS_counts = doc.count_by(spacy.attrs.POS)

for k,v in sorted(POS_counts.items()):
    print(f'{k}. {doc.vocab[k].text:{5}}: {v}')
# Out:
# 84. ADJ  : 53
# 85. ADP  : 125
# 86. ADV  : 63
# 87. AUX  : 49
# 89. CCONJ: 61
# 90. DET  : 90
# 92. NOUN : 172
# 93. NUM  : 9
# 94. PART : 28
# 95. PRON : 110
# 96. PROPN: 74
# 97. PUNCT: 171
# 98. SCONJ: 19
# 100. VERB : 135
# 103. SPACE: 99

# %% [markdown]
# **4. CHALLENGE: What percentage of tokens are nouns?**<br>
# HINT: the attribute ID for 'NOUN' is 91

# %%
total_tokens = len(doc)
noun_tokens = len([token for token in doc if token.pos_ == 'NOUN'])
noun_percentage = (noun_tokens / total_tokens) * 100
noun_percentage
# Out:
# 13.672496025437203

# %% [markdown]
# **5. Display the Dependency Parse for the third sentence**

# %%
displacy.render(list(doc.sents)[2], style='dep', jupyter=True, options={'distance': 110})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="595571c1bf5b4d82970687a65f5f7cfa-0" class="displacy" width="2250" height="412.0" direction="ltr" style="max-width: none; height: 412.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">They</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="160">lived</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="160">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="270">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="270">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="380">their</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="380">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="490">Mother</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="490">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="600">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="600">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="710">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="710">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="820">sand-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="820">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="930">bank,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="930">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="1040">underneath</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1040">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="1150">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1150">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="1260">root</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1260">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="1480">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1480">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="1590">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1590">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">very</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="1810">big</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1810">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="1920">fir-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1920">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="2030">tree.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2030">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="2140">
#
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2140">SPACE</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-595571c1bf5b4d82970687a65f5f7cfa-0-0" stroke-width="2px" d="M70,277.0 C70,222.0 140.0,222.0 140.0,277.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-595571c1bf5b4d82970687a65f5f7cfa-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,279.0 L62,267.0 78,267.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-595571c1bf5b4d82970687a65f5f7cfa-0-1" stroke-width="2px" d="M180,277.0 C180,222.0 250.0,222.0 250.0,277.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-595571c1bf5b4d82970687a65f5f7cfa-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M250.0,279.0 L258.0,267.0 242.0,267.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-595571c1bf5b4d82970687a65f5f7cfa-0-2" stroke-width="2px" d="M400,277.0 C400,222.0 470.0,222.0 470.0,277.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-595571c1bf5b4d82970687a65f5f7cfa-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">poss</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M400,279.0 L392,267.0 408,267.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-595571c1bf5b4d82970687a65f5f7cfa-0-3" stroke-width="2px" d="M290,277.0 C290,167.0 475.0,167.0 475.0,277.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-595571c1bf5b4d82970687a65f5f7cfa-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M475.0,279.0 L483.0,267.0 467.0,267.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-595571c1bf5b4d82970687a65f5f7cfa-0-4" stroke-width="2px" d="M180,277.0 C180,112.0 590.0,112.0 590.0,277.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-595571c1bf5b4d82970687a65f5f7cfa-0-4" class="displacy-label" startOffset="50%" side="left"

# %% [markdown]
# **6. Show the first two named entities from Beatrix Potter's *The Tale of Peter Rabbit* **

# %%
for entity in doc.ents[:2]:
    print(entity.text, entity.label_)
# Out:
# The Tale of Peter Rabbit WORK_OF_ART
# Beatrix Potter PERSON

# %% [markdown]
# **7. How many sentences are contained in *The Tale of Peter Rabbit*?**

# %%
sentences = list(doc.sents)
print("Number of sentences:", len(sentences))
# Out:
# Number of sentences: 55

# %% [markdown]
# **8. CHALLENGE: How many sentences contain named entities?**

# %%
num_sentences_with_entities = 0

for sentence in sentences:
    if any(token.ent_type_ for token in sentence):
        num_sentences_with_entities += 1

num_sentences_with_entities
# Out:
# 35

# %% [markdown]
# **9. CHALLENGE: Display the named entity visualization for `list_of_sents[0]` from the previous problem**

# %%
displacy.render(list(doc.sents)[0], style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Tale of Peter Rabbit
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
# , by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Beatrix Potter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  (
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1902
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ).</br></br></div></span>
